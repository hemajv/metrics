# %% [markdown]
# # GitHub Data Collection
#
# In this notebook, we will fetch the GitHub Issue/PR data for repositories we are interested in using the [MI tool](https://github.com/thoth-station/mi), pre-process the raw data into suitable data frames and store them as parquet files to an s3 bucket. We will also create [Trino](https://trino.io/) tables for the generated parquet files so that we can later create dashboards in [Superset](https://superset.operate-first.cloud/).

# %%
import os
from dotenv import find_dotenv, load_dotenv
import warnings
import trino
from s3_communication import S3Communication

warnings.filterwarnings("ignore")
load_dotenv(find_dotenv())
# Out:
# True

# %%
## Create a .env file on your local with the correct configs
REPO = os.getenv("REPO")
ORG = os.getenv("ORG")
GITHUB_ACCESS_TOKEN = os.getenv("GITHUB_ACCESS_TOKEN")
s3_endpoint_url = os.getenv("S3_ENDPOINT")
aws_access_key_id = os.getenv("S3_ACCESS_KEY")
aws_secret_access_key = os.getenv("S3_SECRET_KEY")
s3_bucket = os.getenv("S3_BUCKET")

# %%
# init s3 connector
s3c = S3Communication(
    s3_endpoint_url, aws_access_key_id, aws_secret_access_key, s3_bucket
)

# %%
repo_slug = f"{ORG}/{REPO}"
repo_slug
# Out:
# 'os-climate/OS-Climate-Community-Hub'

# %%
# Note: The GitHub access token needs to be exported before importing the srcopmetrics package (current bug)
from srcopsmetrics.entities.issue import Issue  # noqa: E402
from srcopsmetrics.entities.pull_request import PullRequest  # noqa: E402

# %%
# Gather the data
# !rm -r srcopsmetrics/
# !python -m srcopsmetrics.cli -clr $repo_slug -e Issue,PullRequest
# Out:
# INFO:srcopsmetrics.github_knowledge:Overall repositories found: 1
# INFO:srcopsmetrics.bot_knowledge:######################## Analysing os-climate/OS-Climate-Community-Hub ########################
#
# INFO:srcopsmetrics.utils:No repo identified, creating new directory at /opt/app-root/src/metrics/notebooks/srcopsmetrics/bot_knowledge/os-climate/OS-Climate-Community-Hub
# INFO:srcopsmetrics.bot_knowledge:########################
# INFO:srcopsmetrics.bot_knowledge:Detected entities:
# CodeFrequency # Commit # DependencyUpdate # Fork # Issue # IssueEvent # KebechetUpdateManager # License # PullRequest # PullRequestDiscussion # RawIssue # RawPullRequest # ReadMe # Release # Stargazer # TrafficClones # TrafficPaths # TrafficPaths # TrafficReferrers # TrafficClones # TrafficViews
# INFO:srcopsmetrics.bot_knowledge:########################
# INFO:srcopsmetrics.bot_knowledge:Issue inspection
# INFO:srcopsmetrics.entities.tools.storage:Loading knowledge locally
# INFO:srcopsmetrics.entities.tools.storage:Data from file %s loaded
# INFO:srcopsmetrics.entities.interface:No previous knowledge of type Issue found
# INFO:srcopsmetrics.iterator:-------------Issue Analysis-------------
# 100%|██████████████████████| 35/35 [00:12<00:00,  2.83it/s, RATE remaining=4859]
# INFO:srcopsmetrics.entities.interface:Knowledge file Issue.json
# INFO:srcopsmetrics.entities.interface:new 31 entities
# INFO:srcopsmetrics.entities.interface:(overall 31 entities)
# INFO:srcopsmetrics.entities.interface:Saved locally at /opt/app-root/src/metrics/notebooks/srcopsmetrics/bot_knowledge/os-climate/OS-Climate-Community-Hub/Issue.json
# INFO:srcopsmetrics.bot_knowledge:
#
# INFO:srcopsmetrics.bot_knowledge:PullRequest inspection
# INFO:srcopsmetrics.entities.tools.storage:Loading knowledge locally
# INFO:srcopsmetrics.entities.tools.storage:Data from file %s loaded
# INFO:srcopsmetrics.entities.interface:No previous knowledge of type PullRequest found
# INFO:srcopsmetrics.iterator:-------------PullRequest Analysis-------------
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #29
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #21
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #19
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/2
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 2/2
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #1
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/1
# 100%|████████████████████████| 4/4 [00:05<00:00,  1.49s/it, RATE remaining=4830]
# INFO:srcopsmetrics.entities.interface:Knowledge file PullRequest.json
# INFO:srcopsmetrics.entities.interface:new 4 entities
# INFO:srcopsmetrics.entities.interface:(overall 4 entities)
# INFO:srcopsmetrics.entities.interface:Saved locally at /opt/app-root/src/metrics/notebooks/srcopsmetrics/bot_knowledge/os-climate/OS-Climate-Community-Hub/PullRequest.json
# INFO:srcopsmetrics.bot_knowledge:

# %%
issue = Issue(repo_slug)
issue_df = issue.load_previous_knowledge(is_local=True)
issue_df.head()
# Out:
#                                            title  \
# id
# 35        Request Onboarding to OSC Data Commons
# 34  Request credentials for an os-climate bucket
# 33  Request credentials for an os-climate bucket
# 32  Request credentials for an os-climate bucket
# 31        Request Onboarding to OSC Data Commons
#
#                                                  body       created_by  \
# id
# 35  Requesting onboarding for github user: @romeok...       oindrillac
# 34  Requesting credentials for github user: mriefe...          mriefer
# 33  Requesting credentials for github user: Christ...  ChristianMeyndt
# 32  Requesting credentials for github user: DaBeID...          DaBeIDS
# 31  Requesting onboarding for github user: mandy-c...   mandy-chessell
#
#             created_at   closed_by           closed_at  \
# id
# 35 2022-05-23 18:05:16        None                 NaT
# 34 2022-05-13 09:02:21        None                 NaT
# 33 2022-05-13 08:59:09        None                 NaT
# 32 2022-05-13 08:54:23        None                 NaT
# 31 2022-05-12 13:28:05  HeatherAck 2022-05-24 15:56:53
#
#                                                labels        interactions
# id
# 35  {'onboarding': {'color': 'DE643F', 'labeled_at...  {'HeatherAck': 13}
# 34                                                 {}                  {}
# 33                                                 {}                  {}
# 32                                                 {}                  {}
# 31  {'onboarding': {'color': 'DE643F', 'labeled_at...  {'HeatherAck': 12}

# %%
issue_df = issue_df.reset_index()

# %%
issue_df.head()
# Out:
#    id                                         title  \
# 0  35        Request Onboarding to OSC Data Commons
# 1  34  Request credentials for an os-climate bucket
# 2  33  Request credentials for an os-climate bucket
# 3  32  Request credentials for an os-climate bucket
# 4  31        Request Onboarding to OSC Data Commons
#
#                                                 body       created_by  \
# 0  Requesting onboarding for github user: @romeok...       oindrillac
# 1  Requesting credentials for github user: mriefe...          mriefer
# 2  Requesting credentials for github user: Christ...  ChristianMeyndt
# 3  Requesting credentials for github user: DaBeID...          DaBeIDS
# 4  Requesting onboarding for github user: mandy-c...   mandy-chessell
#
#            created_at   closed_by           closed_at  \
# 0 2022-05-23 18:05:16        None                 NaT
# 1 2022-05-13 09:02:21        None                 NaT
# 2 2022-05-13 08:59:09        None                 NaT
# 3 2022-05-13 08:54:23        None                 NaT
# 4 2022-05-12 13:28:05  HeatherAck 2022-05-24 15:56:53
#
#                                               labels        interactions
# 0  {'onboarding': {'color': 'DE643F', 'labeled_at...  {'HeatherAck': 13}
# 1                                                 {}                  {}
# 2                                                 {}                  {}
# 3                                                 {}                  {}
# 4  {'onboarding': {'color': 'DE643F', 'labeled_at...  {'HeatherAck': 12}

# %%
# Retain only relevant columns
issue_cols_to_drop = ["labels", "interactions"]
issue_df = issue_df.drop(columns=issue_cols_to_drop)
issue_df["org"] = ORG
issue_df["repo"] = REPO

issue_df.head()
# Out:
#    id                                         title  \
# 0  35        Request Onboarding to OSC Data Commons
# 1  34  Request credentials for an os-climate bucket
# 2  33  Request credentials for an os-climate bucket
# 3  32  Request credentials for an os-climate bucket
# 4  31        Request Onboarding to OSC Data Commons
#
#                                                 body       created_by  \
# 0  Requesting onboarding for github user: @romeok...       oindrillac
# 1  Requesting credentials for github user: mriefe...          mriefer
# 2  Requesting credentials for github user: Christ...  ChristianMeyndt
# 3  Requesting credentials for github user: DaBeID...          DaBeIDS
# 4  Requesting onboarding for github user: mandy-c...   mandy-chessell
#
#            created_at   closed_by           closed_at         org  \
# 0 2022-05-23 18:05:16        None                 NaT  os-climate
# 1 2022-05-13 09:02:21        None                 NaT  os-climate
# 2 2022-05-13 08:59:09        None                 NaT  os-climate
# 3 2022-05-13 08:54:23        None                 NaT  os-climate
# 4 2022-05-12 13:28:05  HeatherAck 2022-05-24 15:56:53  os-climate
#
#                        repo
# 0  OS-Climate-Community-Hub
# 1  OS-Climate-Community-Hub
# 2  OS-Climate-Community-Hub
# 3  OS-Climate-Community-Hub
# 4  OS-Climate-Community-Hub

# %%
# Upload the processed df to s3 as a parquet file
s3c.upload_df_to_s3(
    df=issue_df,
    s3_prefix="open-services-group/metrics/github/os-climate/issues",
    s3_key=f"{ORG}-{REPO}.parquet",
)
# Out:
# {'ResponseMetadata': {'RequestId': 'tx000000000000000016cc3-00628fbd0a-f6835f-ocs-storagecluster-cephobjectstore',
#   'HostId': '',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'content-length': '0',
#    'etag': '"daa6440b3eb57b30a4584ca6147a1cdc"',
#    'accept-ranges': 'bytes',
#    'x-amz-request-id': 'tx000000000000000016cc3-00628fbd0a-f6835f-ocs-storagecluster-cephobjectstore',
#    'date': 'Thu, 26 May 2022 17:46:50 GMT',
#    'set-cookie': 'bbdcd938787a45e68f8d240a4e2dadcf=9305a9992645bb0698c9f5d65ae10c7e; path=/; HttpOnly'},
#   'RetryAttempts': 0},
#  'ETag': '"daa6440b3eb57b30a4584ca6147a1cdc"'}

# %%
pr = PullRequest(repo_slug)
pr_df = pr.load_previous_knowledge(is_local=True)
pr_df.head()
# Out:
#                                      title  \
# id
# 29                  Add OPF OSC board view
# 21  Add request credentials issue template
# 19                     Onboarding template
# 1       Thoth Configuration Initialization
#
#                                                  body size     created_by  \
# id
# 29  Signed-off-by: Erik Erlandson <eerlands@redhat...   XS  erikerlandson
# 21                  Fixes #20 \r\n\r\n@erikerlandson     S     Shreyanand
# 19                                          Fixes #15    S  erikerlandson
# 1   ## Automatic configuration initialization\nThe...    M   khebhut[bot]
#
#             created_at           closed_at      closed_by           merged_at  \
# id
# 29 2022-05-05 22:03:10 2022-05-05 22:03:43  erikerlandson 2022-05-05 22:03:43
# 21 2022-04-05 20:12:05 2022-04-06 16:06:15  erikerlandson 2022-04-06 16:06:15
# 19 2022-03-25 18:47:18 2022-03-28 14:58:29     HeatherAck 2022-03-28 14:58:29
# 1  2022-01-28 18:51:07 2022-01-28 19:47:23     HeatherAck 2022-01-28 19:47:23
#
#         merged_by  commits_number  changed_files_number  \
# id
# 29  erikerlandson               1                     1
# 21  erikerlandson               1                     1
# 19     HeatherAck               1                     1
# 1      HeatherAck               1                     1
#
#                              interactions  \
# id
# 29                                     {}
# 21  {'Shreyanand': 1, 'erikerlandson': 4}
# 19                 {'erikerlandson': 153}
# 1                                      {}
#
#                                               reviews labels  \
# id
# 29                                                 {}     []
# 21                                                 {}     []
# 19  {'923289967': {'author': 'HeatherAck', 'words_...     []
# 1   {'866646009': {'author': 'HeatherAck', 'words_...     []
#
#                                        commits  \
# id
# 29  [18bbf9c1779aa1ad7474533a7d88e17f3a4ffc96]
# 21  [7f495d13d687feb4cac247cd57f0ea8996ad1538]
# 19  [fc18e481d703fc0039da25577a13ca545a38c273]
# 1   [f2fe0ca0f227c78ca07bb883bbb493b52bcd3e35]
#
#                                         changed_files     first_review_at  \
# id
# 29                                        [README.md]                 NaT
# 21  [.github/ISSUE_TEMPLATE/request-credentials-fo...                 NaT
# 19  [.github/ISSUE_TEMPLATE/request-onboarding-to-... 2022-03-28 14:57:07
# 1                                       [.thoth.yaml] 2022-01-28 19:47:13
#
#       first_approve_at
# id
# 29                 NaT
# 21                 NaT
# 19 2022-03-28 14:57:07
# 1  2022-01-28 19:47:13

# %%
pr_df = pr_df.reset_index()

# %%
pr_df.head()
# Out:
#    id                                   title  \
# 0  29                  Add OPF OSC board view
# 1  21  Add request credentials issue template
# 2  19                     Onboarding template
# 3   1      Thoth Configuration Initialization
#
#                                                 body size     created_by  \
# 0  Signed-off-by: Erik Erlandson <eerlands@redhat...   XS  erikerlandson
# 1                  Fixes #20 \r\n\r\n@erikerlandson     S     Shreyanand
# 2                                          Fixes #15    S  erikerlandson
# 3  ## Automatic configuration initialization\nThe...    M   khebhut[bot]
#
#            created_at           closed_at      closed_by           merged_at  \
# 0 2022-05-05 22:03:10 2022-05-05 22:03:43  erikerlandson 2022-05-05 22:03:43
# 1 2022-04-05 20:12:05 2022-04-06 16:06:15  erikerlandson 2022-04-06 16:06:15
# 2 2022-03-25 18:47:18 2022-03-28 14:58:29     HeatherAck 2022-03-28 14:58:29
# 3 2022-01-28 18:51:07 2022-01-28 19:47:23     HeatherAck 2022-01-28 19:47:23
#
#        merged_by  commits_number  changed_files_number  \
# 0  erikerlandson               1                     1
# 1  erikerlandson               1                     1
# 2     HeatherAck               1                     1
# 3     HeatherAck               1                     1
#
#                             interactions  \
# 0                                     {}
# 1  {'Shreyanand': 1, 'erikerlandson': 4}
# 2                 {'erikerlandson': 153}
# 3                                     {}
#
#                                              reviews labels  \
# 0                                                 {}     []
# 1                                                 {}     []
# 2  {'923289967': {'author': 'HeatherAck', 'words_...     []
# 3  {'866646009': {'author': 'HeatherAck', 'words_...     []
#
#                                       commits  \
# 0  [18bbf9c1779aa1ad7474533a7d88e17f3a4ffc96]
# 1  [7f495d13d687feb4cac247cd57f0ea8996ad1538]
# 2  [fc18e481d703fc0039da25577a13ca545a38c273]
# 3  [f2fe0ca0f227c78ca07bb883bbb493b52bcd3e35]
#
#                                        changed_files     first_review_at  \
# 0                                        [README.md]                 NaT
# 1  [.github/ISSUE_TEMPLATE/request-credentials-fo...                 NaT
# 2  [.github/ISSUE_TEMPLATE/request-onboarding-to-... 2022-03-28 14:57:07
# 3                                      [.thoth.yaml] 2022-01-28 19:47:13
#
#      first_approve_at
# 0                 NaT
# 1                 NaT
# 2 2022-03-28 14:57:07
# 3 2022-01-28 19:47:13

# %%
# Retain only relevant columns
pr_cols_to_drop = ["interactions", "reviews", "labels", "commits", "changed_files"]
prs_df = pr_df.drop(columns=pr_cols_to_drop)
prs_df["org"] = ORG
prs_df["repo"] = REPO

prs_df.head()
# Out:
#    id                                   title  \
# 0  29                  Add OPF OSC board view
# 1  21  Add request credentials issue template
# 2  19                     Onboarding template
# 3   1      Thoth Configuration Initialization
#
#                                                 body size     created_by  \
# 0  Signed-off-by: Erik Erlandson <eerlands@redhat...   XS  erikerlandson
# 1                  Fixes #20 \r\n\r\n@erikerlandson     S     Shreyanand
# 2                                          Fixes #15    S  erikerlandson
# 3  ## Automatic configuration initialization\nThe...    M   khebhut[bot]
#
#            created_at           closed_at      closed_by           merged_at  \
# 0 2022-05-05 22:03:10 2022-05-05 22:03:43  erikerlandson 2022-05-05 22:03:43
# 1 2022-04-05 20:12:05 2022-04-06 16:06:15  erikerlandson 2022-04-06 16:06:15
# 2 2022-03-25 18:47:18 2022-03-28 14:58:29     HeatherAck 2022-03-28 14:58:29
# 3 2022-01-28 18:51:07 2022-01-28 19:47:23     HeatherAck 2022-01-28 19:47:23
#
#        merged_by  commits_number  changed_files_number     first_review_at  \
# 0  erikerlandson               1                     1                 NaT
# 1  erikerlandson               1                     1                 NaT
# 2     HeatherAck               1                     1 2022-03-28 14:57:07
# 3     HeatherAck               1                     1 2022-01-28 19:47:13
#
#      first_approve_at         org                      repo
# 0                 NaT  os-climate  OS-Climate-Community-Hub
# 1                 NaT  os-climate  OS-Climate-Community-Hub
# 2 2022-03-28 14:57:07  os-climate  OS-Climate-Community-Hub
# 3 2022-01-28 19:47:13  os-climate  OS-Climate-Community-Hub

# %%
# Upload the processed df to s3 as a parquet file
s3c.upload_df_to_s3(
    df=prs_df,
    s3_prefix="open-services-group/metrics/github/os-climate/prs",
    s3_key=f"{ORG}-{REPO}.parquet",
)
# Out:
# {'ResponseMetadata': {'RequestId': 'tx000000000000000016cc4-00628fbd0c-f6835f-ocs-storagecluster-cephobjectstore',
#   'HostId': '',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'content-length': '0',
#    'etag': '"2cb47de22b4b4ebc639d7c8ba34dc9e5"',
#    'accept-ranges': 'bytes',
#    'x-amz-request-id': 'tx000000000000000016cc4-00628fbd0c-f6835f-ocs-storagecluster-cephobjectstore',
#    'date': 'Thu, 26 May 2022 17:46:52 GMT',
#    'set-cookie': 'bbdcd938787a45e68f8d240a4e2dadcf=9305a9992645bb0698c9f5d65ae10c7e; path=/; HttpOnly'},
#   'RetryAttempts': 0},
#  'ETag': '"2cb47de22b4b4ebc639d7c8ba34dc9e5"'}

# %%
# Map the datatype columns of df to suitable datatype supported in Trino/Superset
_p2smap = {
    "object": "varchar",
    "int64": "bigint",
    "float64": "double",
    "datetime64[ns]": "timestamp",
    "bool": "boolean",
}


def pandas_type_to_sql(pt):
    st = _p2smap.get(pt)
    if st is not None:
        return st
    raise ValueError("unexpected pandas column type '{pt}'".format(pt=pt))


# Generate the Trino table schema
def generate_table_schema_pairs(df):
    ptypes = [str(e) for e in df.dtypes.to_list()]
    stypes = [pandas_type_to_sql(e) for e in ptypes]
    pz = list(zip(df.columns.to_list(), stypes))
    return ",\n".join(["    {n} {t}".format(n=e[0], t=e[1]) for e in pz])

# %%
# Create a Trino client
conn = trino.dbapi.connect(
    auth=trino.auth.BasicAuthentication(
        os.environ["TRINO_USER"], os.environ["TRINO_PASSWD"]
    ),
    host=os.environ["TRINO_HOST"],
    port=int(os.environ["TRINO_PORT"]),
    http_scheme="https",
    verify=True,
)
cur = conn.cursor()

# %%
# Check if Trino connection was successful
cur.execute("show catalogs")
cur.fetchall()[1]
# Out:
# ['data_science_general']

# %%
# Create the issues table with data populated from parquet file
issue_schema = generate_table_schema_pairs(issue_df)

tabledef = """create table if not exists data_science_general.default.os_climate_issues(
{schema}
) with (
    format = 'parquet',
    external_location = 's3a://{s3_bucket}/open-services-group/metrics/github/os-climate/issues'
)""".format(
    schema=issue_schema,
    s3_bucket=os.environ["S3_BUCKET"],
)

cur.execute(tabledef)
cur.fetchall()

# %%
# Create the PR table with data populated from parquet file
pr_schema = generate_table_schema_pairs(prs_df)

tabledef = """create table if not exists data_science_general.default.os_climate_prs(
{schema}
) with (
    format = 'parquet',
    external_location = 's3a://{s3_bucket}/open-services-group/metrics/github/os-climate/prs'
)""".format(
    schema=pr_schema,
    s3_bucket=os.environ["S3_BUCKET"],
)

cur.execute(tabledef)
cur.fetchall()
